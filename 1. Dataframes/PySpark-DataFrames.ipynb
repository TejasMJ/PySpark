# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Checking if pyspark is working 
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fb0d85288f1d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Dataframe</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
#reading the Dataframe
df_pyspark = spark.read.option('header','true').csv('/content/drive/MyDrive/Python/1. Dataframes/Test1.csv', inferSchema=True)

# %%
## Check the Schema
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/Python/1. Dataframes/Test1.csv', header=True,inferSchema=True)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# |     Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
# Column names
df_pyspark.columns
# Out:
# ['Name', 'Age', 'Experience']

# %%
df_pyspark.head(2) #Output will be a list
# Out:
# [Row(Name='Krish', Age=31, Experience=10),
#  Row(Name='Sudhanshu', Age=30, Experience=8)]

# %%
df_pyspark.select('Name').show()
# Out:
# +---------+
# |     Name|
# +---------+
# |    Krish|
# |Sudhanshu|
# |    Sunny|
# +---------+

# %%
df_pyspark.select(['Name','Experience']).show()
# Out:
# +---------+----------+
# |     Name|Experience|
# +---------+----------+
# |    Krish|        10|
# |Sudhanshu|         8|
# |    Sunny|         4|
# +---------+----------+

# %%
df_pyspark.dtypes
# Out:
# [('Name', 'string'), ('Age', 'int'), ('Experience', 'int')]

# %%
#Describe option

df_pyspark.describe()
df_pyspark.describe().show()
# Out:
# +-------+-----+----+-----------------+
# |summary| Name| Age|       Experience|
# +-------+-----+----+-----------------+
# |  count|    3|   3|                3|
# |   mean| null|30.0|7.333333333333333|
# | stddev| null| 1.0|3.055050463303893|
# |    min|Krish|  29|                4|
# |    max|Sunny|  31|               10|
# +-------+-----+----+-----------------+

# %%
#Adding Columns in DataFrame

df_pyspark = df_pyspark.withColumn('Experience After 2 Years', df_pyspark['Experience']+2)

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+------------------------+
# |     Name|Age|Experience|Experience After 2 Years|
# +---------+---+----------+------------------------+
# |    Krish| 31|        10|                      12|
# |Sudhanshu| 30|         8|                      10|
# |    Sunny| 29|         4|                       6|
# +---------+---+----------+------------------------+

# %%
#Dropping Columns in DataFrame

df_pyspark = df_pyspark.drop('Experience After 2 Years')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# |     Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+

# %%
#Renaming the Column Name
df_pyspark = df_pyspark.withColumnRenamed('Name', 'New Name')

# %%
df_pyspark.show()
# Out:
# +---------+---+----------+
# | New Name|Age|Experience|
# +---------+---+----------+
# |    Krish| 31|        10|
# |Sudhanshu| 30|         8|
# |    Sunny| 29|         4|
# +---------+---+----------+
