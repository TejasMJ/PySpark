# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 12.3 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.2-py2.py3-none-any.whl size=281824025 sha256=aeef54333c367b781af8f4688c41f41fe2ab5df78f6af3b4832158f98eda3b50
#   Stored in directory: /root/.cache/pip/wheels/6c/e3/9b/0525ce8a69478916513509d43693511463c6468db0de237c86
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
import pandas as pd

# %%
pd.read_csv('/content/drive/MyDrive/Python/Test1.csv')
# Out:
#         Name  Age
# 0      Krish   31
# 1  Sudhanshu   30
# 2      Sunny   29

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10b9109cd118:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('/content/drive/MyDrive/Python/Test1.csv')
df_pyspark.show()
# Out:
# +---------+---+
# |      _c0|_c1|
# +---------+---+
# |     Name|Age|
# |    Krish| 31|
# |Sudhanshu| 30|
# |    Sunny| 29|
# +---------+---+

# %%
df_pyspark = spark.read.option('header','true').csv('/content/drive/MyDrive/Python/Test1.csv')
df_pyspark.show()
# Out:
# +---------+---+
# |     Name|Age|
# +---------+---+
# |    Krish| 31|
# |Sudhanshu| 30|
# |    Sunny| 29|
# +---------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)
